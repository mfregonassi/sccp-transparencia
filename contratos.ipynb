# %%
import sys
# !{sys.executable} -m pip install requests
import requests
import json
import math
from datetime import date

# %%
# Extracting data

club = 78 # Corinthians
gender = 'M'
professional = []

page_num = 0
while(True):
    response = requests.get(f'https://futebolpaulista.com.br/Handlers/Atleta/ListarAtletas.ashx?IdClube={club}&pageNum={page_num}')
    json_response = json.loads(response.text)
    pagination = json_response['Pagination']
    if pagination == False:
        break
    players = json_response['Retorno']
    for player in players:
        if player['Sexo'] == gender:
            player_id = player['IdAtleta']
            player_cat = player['Categoria']
            response2 = requests.get(f'https://futebolpaulista.com.br/Handlers/Atleta/ReadAtleta.ashx?IdAtleta={player_id}')
            json_response2 = json.loads(response2.text)
            player_data = json_response2['Retorno']
            age = player_data['Anos']
            year_age = int(player_data['DataNascimento'][-4:])
            if player_cat == 'P' or age >= 16:
                if year_age >= 2004:
                    player_data['Grupo'] = 'S17'
                elif year_age >= 2001:
                    player_data['Grupo'] = 'S20'
                elif year_age >= 1998:
                    player_data['Grupo'] = 'S23'
                else:
                    player_data['Grupo'] = '23+'
                player_data['Categoria'] = player_cat
                professional.append(player_data)
    page_num += 1
    
with open(f'./data/{date.today().strftime("%Y%m%d")}.json', 'w', encoding='utf-8') as f:
    json.dump(professional, f, ensure_ascii=False, indent=4)

# %%
with open(f'./data/{date.today().strftime("%Y%m%d")}.json') as f:
    players = json.load(f)

u_17_p = 0
u_17_a = 0
u_20_p = 0
u_20_a = 0
u_23_p = 0
u_23_a = 0
o_23_p = 0
o_23_a = 0

for player in players:
    cat = player['Categoria']
    group = player['Grupo']
    if cat == 'A':
        if group == 'S17':
            u_17_a += 1
        elif group == 'S20':
            u_20_a += 1
        elif group == 'S23':
            u_23_a += 1
        elif group == '23+':
            o_23_a += 1
    elif cat == 'P':
        if group == 'S17':
            u_17_p += 1
        elif group == 'S20':
            u_20_p += 1
        elif group == 'S23':
            u_23_p += 1
        elif group == '23+':
            o_23_p += 1
                 
u_17 = u_17_p + u_17_a
u_20 = u_20_p + u_20_a
u_23 = u_23_p + u_23_a
o_23 = o_23_p + o_23_a
num_a = u_17_a + u_20_a + u_23_a + o_23_a
num_p = u_17_p + u_20_p + u_23_p + o_23_p
num_players = num_a + num_p

# %%
next_6 = ['03/2021', '04/2021', '05/2021', '06/2021', '07/2021', '08/2021']
expiring_0 = []
expiring_1 = []
expiring_2 = []
expiring_3 = []
expiring_4 = []
expiring_5 = []
expiring_21 = []
expiring_22 = []
expiring_23 = []
expiring_24 = []
expiring_25 = []
expiring_26 = []

for player in players:
    contract_end = player['DataTerminoContrato']
    if contract_end.endswith(next_6[0]):
        expiring_0.append(player)
    elif contract_end.endswith(next_6[1]):
        expiring_1.append(player)
    elif contract_end.endswith(next_6[2]):
        expiring_2.append(player)
    elif contract_end.endswith(next_6[3]):
        expiring_3.append(player)
    elif contract_end.endswith(next_6[4]):
        expiring_4.append(player)
    elif contract_end.endswith(next_6[5]):
        expiring_5.append(player)
    elif contract_end.endswith('2021'):
        expiring_21.append(player)
    elif contract_end.endswith('2022'):
        expiring_22.append(player)
    elif contract_end.endswith('2023'):
        expiring_23.append(player)
    elif contract_end.endswith('2024'):
        expiring_24.append(player)
    elif contract_end.endswith('2025'):
        expiring_25.append(player)
    elif contract_end.endswith('2026'):
        expiring_26.append(player)
    else:
        continue

# %%
print(f'{num_players} jogadores acima de 16 anos sob contrato')
print(f'{num_p} com contratos profissionais, {num_a} amadores')
print('')
print(f'{u_17} sub-17, {u_17_p} com contratos profissionais, {u_17_a} amadores')
print(f'{u_20} sub-20, {u_20_p} com contratos profissionais, {u_20_a} amadores')
print(f'{u_23} sub-23, {u_23_p} com contratos profissionais, {u_23_a} amadores')
print(f'{o_23} acima de 23, {o_23_p} com contratos profissionais, {o_23_a} amadores')
print('')
print(f'Expirando em {next_6[0]}:')
for player in expiring_0:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
print('')    
print(f'Expirando em {next_6[1]}:')
for player in expiring_1:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
print('')    
print(f'Expirando em {next_6[2]}:')
for player in expiring_2:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
print('')
print(f'Expirando em {next_6[3]}:')
for player in expiring_3:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
print('')
print(f'Expirando em {next_6[4]}:')
for player in expiring_4:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
print('')
print(f'Expirando em {next_6[5]}:')
for player in expiring_5:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
print('')
print('---')
print(f'Outros {len(expiring_21)} contratos expirando em 2021')
print(f'{len(expiring_22)} contratos expirando em 2022')
print(f'{len(expiring_23)} contratos expirando em 2023')
print('')
print(f'{len(expiring_24)} contratos expirando em 2024:')
for player in expiring_24:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
print('')
print(f'{len(expiring_25)} contratos expirando em 2025:')
for player in expiring_25:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
print('')
print(f'{len(expiring_26)} contratos expirando em 2026:')
for player in expiring_26:
    name = player['Nome']
    age = player['Anos']
    contract_end = player['DataTerminoContrato']
    print(f'{name} ({age}) - {contract_end}')
# Out:
# 139 jogadores acima de 16 anos sob contrato
# 108 com contratos profissionais, 31 amadores
#
# 26 sub-17, 6 com contratos profissionais, 20 amadores
# 51 sub-20, 40 com contratos profissionais, 11 amadores
# 37 sub-23, 37 com contratos profissionais, 0 amadores
# 25 acima de 23, 25 com contratos profissionais, 0 amadores
#
# Expirando em 03/2021:
# Rafael Baldini Massola (21) - 22/03/2021
# Ronald Eugenio de Carvalho (20) - 31/03/2021
# Wallace Lucas Aires da Silva (23) - 31/03/2021
#
# Expirando em 04/2021:
# Reifit Alves de Faria (19) - 20/04/2021
#
# Expirando em 05/2021:
# Eduardo GonÃ§alves Blanco (21) - 31/05/2021
# EugÃªnio Marques Ferreira (22) - 10/05/2021
# Gabriel de Paula Ferreira (20) - 20/05/2021
# Murilo Puliero (16) - 20/05/2021
# Willian da Silva Felix (22) - 31/05/2021
#
# Expirando em 06/2021:
# Caio de Lucca Oliveira Maltas (17) - 19/06/2021
# Victor Danilo Cantillo Jimenez (27) - 30/06/2021
# Juan Ramon Cazares Sevillano (28) - 30/06/2021
# Gildomar da Silva Ferreira (22) - 03/06/2021
# Jemerson de Jesus Nascimento (28) - 30/06/2021
# Romulo Otero Vasquez (28) - 30/06/2021
#
# Expirando em 07/2021:
# Alexandre Manoel Mantelli Martinez (18) - 31/07/2021
# Antony Alves Santos (19) - 14/07/2021
# Daniel Marcos Meira Novaes (19) - 31/07/2021
# Juan David Torres Henriquez (19) - 18/07/2021
#
# Expirando em 08/2021:
# Julio Henrique de Lacerda de Paula (18) - 30/08/2021
# Richard Caimmy Marcondes dos Santos (19) - 31/08/2021
#
# ---
# Outros 16 contratos expirando em 2021
# 62 contratos expirando em 2022
# 32 contratos expirando em 2023
#
# 5 contratos expirando em 2024:
# JoÃ£o Victor Tornich (18) - 31/01/2024
# Caio Cesar Paz Moraes (17) - 01/02/2024
# JosÃ© Eduardo Bitencourt da Silva (18) - 31/10/2024
# Leonardo Natel Vieira (23) - 31/12/2024
# Raul Gustavo Pereira Bicalho (21) - 31/12/2024
#
# 3 contratos expirando em 2025:
# Ederson Jose dos Santos Lourenco da Silva (21) - 31/01/2025
# Gustavo Mantuan (19) - 05/01/2025
# Matheus Planelles Donelli (18) - 05/01/2025
#
# 0 contratos expirando em 2026:

# %%
# U-17

for player in players:
    group = player['Grupo']
    if group == 'S17':
        print(f"{player['Nome']} ({player['Categoria']})")
# Out:
# Arllan Pedro Barbosa da Silva (P)
# Breno de Souza Bidon (A)
# Caio Cesar Paz Moraes (A)
# Caio de Jesus Santos (A)
# Carlos Eduardo Coutinho de Goes (A)
# Fabio Ricci Fernandes Abreu (A)
# Felipe Augusto da Silva (P)
# Felipe Longo Fernandes da Silva (A)
# Gabriel Henrique Soares da Silva (A)
# Guilherme Sucigan Mafra Cunha (P)
# Gustavo Ferreira de Almeida (A)
# Idelmindo Cardoso Nunes Filho (P)
# KauÃª Vinicius de Souza Camargo (A)
# Leonardo Mana Hernandes (A)
# Luis Fernando Albuquerque Barbosa (A)
# Luiz Felipe Rodrigues Farias Santos (A)
# Miguel Henrique de Souza Silva (A)
# Murilo Puliero (A)
# Pedro Herinque de Assis (A)
# Renato Santos da Cruz (P)
# Thomas Rafael GonÃ§alves Lisboa (A)
# Thomas Agustin Fretes (P)
# Victor Marcelo Mendes de Santana (A)
# Vinicius Cressi (A)
# Wendel Alves GonÃ§alves (A)
# Wesley Gassova Ribeiro Teixeira (A)

# %%
# U-20

for player in players:
    group = player['Grupo']
    if group == 'S20':
        print(f"{player['Nome']} ({player['Categoria']})")
# Out:
# Alan Ferreira de Amorim (P)
# Alan Gobetti Silva (P)
# JoÃ£o Victor Tornich (P)
# Alexandre Manoel Mantelli Martinez (P)
# Antony Alves Santos (P)
# Matheus de AraÃºjo Andrade (P)
# Arthur Sousa AraÃºjo (P)
# Lucas Belezi Barbosa (P)
# Bruno Gabriel de Souza Alves (A)
# Bryan Christian Lemos de Carvalho (P)
# Caio de Lucca Oliveira Maltas (A)
# Caique Nunes Vilas Boas (P)
# Cauan Vieira da Mata (A)
# Caue Vinicius dos Santos (P)
# Daniel Marcos Meira Novaes (P)
# David Henrique Benedito Benjamim (A)
# Eduardo Fraga Capellari (P)
# Gabriel Dias dos Santos (P)
# Gabriel dos Santos Gallegos (P)
# Gabriel dos Santos Oliveira (A)
# Gabriel Pereira dos Santos (P)
# Guilherme dos Santos Gallegos (P)
# Gustavo Mantuan (P)
# Jonathan dos Santos Lessa (P)
# JoÃ£o Pedro de Sousa Rodrigues (P)
# Joesley da Silva Cordeiro (A)
# JosÃ© Eduardo Bitencourt da Silva (P)
# Juan David Torres Henriquez (P)
# Julio Henrique de Lacerda de Paula (P)
# Wendell Fernandes da Silva (P)
# Keven Vinicius Duarte Silva (P)
# Leonardo dos Santos Lopes da Silva (P)
# Luan Vitor Moreira Serafim (P)
# Lucas Pires Silva (P)
# Luis Gustavo da Silva Machado Duarte (P)
# Matheus Planelles Donelli (P)
# Matheus Schultz (A)
# Max Yam Suzano dos Santos (A)
# Murillo Santiago Costa dos Santos (P)
# Reginaldo de Lima Nunes Junior (P)
# Reifit Alves de Faria (P)
# Richard Caimmy Marcondes dos Santos (P)
# Richard Cossoniche da Silva (P)
# Riquelme Rodrigues Mendes (P)
# Robert Renan Alves Barbosa (P)
# Rodrigo Daniel da Silva Bernardo (A)
# Rodrigo Santos Varanda (P)
# Ronald Ferreira Barbosa (A)
# Ryan Gustavo de Lima (A)
# Thaigo Pereira Reynaldo (P)
# Thalisson Gabriel Vieira Silva (P)

# %%
# U-23

for player in players:
    group = player['Grupo']
    if group == 'S23':
        print(f"{player['Nome']} ({player['Categoria']})")
# Out:
# Adson Ferreira Soares (P)
# Bruno Mendez Cittadini (P)
# Roni Medeiros de Moura (P)
# Ederson Jose dos Santos Lourenco da Silva (P)
# Eduardo Santos Queiroz (P)
# Eduardo GonÃ§alves Blanco (P)
# EugÃªnio Marques Ferreira (P)
# Fabricio Keiske Rodrigues Oya (P)
# Felipe Alexandre Cruz Torres (P)
# Jefferson Gabriel Nascimento Brito (P)
# Filipe GonÃ§alves dos Santos (P)
# Igor Marques Paciencia Cardoso (P)
# Gabriel Araujo dos Santos (P)
# Gabriel de Paula Ferreira (P)
# Gildomar da Silva Ferreira (P)
# Heitor Casagrande Zani (P)
# Hugo da ConceiÃ§Ã£o Medeiros (P)
# Igor Morais Carvalho (P)
# Janderson Santos de Souza (P)
# JoÃ£o Victor da Silva Marcelino (P)
# John Kleber Oliveira da Silva (P)
# Kaue Moreira de Souza (P)
# HÃ­gor Lapa Azevedo (P)
# Leonardo Rodrigues dos Santos (P)
# Leonardo Paraiso de Almeida (P)
# Madson de Souza Silva (P)
# Matheus Matias Ferreira (P)
# Matheus Alvarenga de Oliveira (P)
# Mateus da Silva Vital AssumpÃ§Ã£o (P)
# Lucas Piton Crivellaro (P)
# Rafael Baldini Massola (P)
# Raul Gustavo Pereira Bicalho (P)
# Ronald Eugenio de Carvalho (P)
# Ruan de Oliveira Ferreira (P)
# Guilherme Vicentini Castellani (P)
# Victor Gabriel Moura de Oliveira (P)
# Willian da Silva Felix (P)
